# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:98f12bff-c728-4496-a07d-c1a7c41f243e.png)

# %%
z = 0.374 * 25.4e-3
r = 0.227 * 25.4e-3
mu0 = 4 * np.pi * 1e-7
L = mu0 * np.pi * r**2 / z
print(L / 1e-9, "nH")
ke = 1.000586
epilson0 = 8.8541878188e-12
w = 0.024 * 25.4e-3
t = 0.033 * 25.4e-3
n = 1
C = ke * epilson0 * w * z / t / n
print(C / 1e-12, "pF")
C = C + 1e-12
v0 = 1 / 2 / np.pi / np.sqrt(L * C)
print(v0 / 1e9)
# Out:
# 13.8157213557934 nH
# 0.061207659484827724 pF
# 1.3144169803522843

# %%
z = 0.261 * 25.4e-3
r = 0.188 / 2 * 25.4e-3
mu0 = 4 * np.pi * 1e-7
L = mu0 * np.pi * r**2 / z
print(L / 1e-9, "nH")
ke = 1.000586
epilson0 = 8.8541878188e-12
w = 0.018 * 25.4e-3
t = 0.026 * 25.4e-3
n = 1
C = ke * epilson0 * w * z / t / n
print(C / 1e-12, "pF")
C = C + 12e-12
v0 = 1 / 2 / np.pi / np.sqrt(L * C)
print(v0 / 1e9)
# Out:
# 3.3947566927139445 nH
# 0.04066085750278856 pF
# 0.7872100737432226

# %%
z = 0.261 * 25.4e-3
r = 0.188 / 2 * 25.4e-3
mu0 = 4 * np.pi * 1e-7
L = mu0 * np.pi * r**2 / z
print(L / 1e-9, "nH")
ke = 1.000586
epilson0 = 8.8541878188e-12
w = 0.005 * 25.4e-3 
t = 0.026 * 25.4e-3
n = 1
C = ke * epilson0 * w * z / t / n
print(C / 1e-12, "pF")
C = C + 1.5e-12 + 12e-12
v0 = 1 / 2 / np.pi / np.sqrt(L * C)
print(v0 / 1e9)
# Out:
# 3.3947566927139445 nH
# 0.01129468263966349 pF
# 0.7431343256609307

# %% [markdown]
# pF: 12 pF
# resonance at 800 MHz
# either check touching, or put on 12 pF

# %% [markdown]
# - cleared copper in gap
# - - just 12 pF, still 790 MHz
#   - 12 pF and 1.5 - 5 pF => 950 MHz to 1540 MHz (half a turn, no end)
