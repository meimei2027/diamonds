# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_modulation(t, edges):
    y = np.zeros_like(t)
    for on, off in zip(edges[0::2], edges[1::2]):
        y[(t >= on) & (t < off)] = 1
    return t, y

# %%
MAX_SAMPLE_RATE = 250e6
duration = 10e-6
edges = [0e-6, 10e-6]

num_samples = int(MAX_SAMPLE_RATE * duration)
t = np.arange(num_samples) / MAX_SAMPLE_RATE
_, mod = generate_modulation(t, edges)

fig, ax = plt.subplots()
ax.plot(t, mod)

# %%
def load_csv(csv_file):
    data = np.genfromtxt(csv_file, delimiter=",", skip_header=1)
    t = np.asarray(data[:, 0], dtype=np.float32)
    ch1 = np.asarray(data[:, 1], dtype=np.float32)
    # ch2 = np.asarray(data[:, 2], dtype=np.float32)
    return t, ch1

def compute_fft(t, y):
    dt = t[1] - t[0]
    N = len(y)
    Y = np.fft.fft(y)
    f = np.fft.fftfreq(N, d=dt)

    Y = np.fft.fftshift(Y)
    f = np.fft.fftshift(f)

    return f, Y / len(y)

def get_peak_freq(t, y):
    mask = t > 0
    f, Y = compute_fft(t[mask], y[mask])
    Y = np.abs(Y)
    fig, ax = plt.subplots()
    ax.plot(f, Y)
    return np.abs(f[np.argmax(Y)]) / 1e6

t, ch1 = load_csv("./waveforms/sdg1062x.csv")
fig, ax = plt.subplots()
ax.plot(t, ch1)
print(len(ch1))
waveform = ch1 * 32767
# -32768~32767

ax.plot(t, waveform)
# Out:
# 300

# %%
fig, ax = plt.subplots()
t, ch1 = load_csv("D:/data/WFMNEW03.CSV")
ax.plot(t, ch1)
print(get_peak_freq(t, ch1))
t2, ch12 = load_csv("D:/data/WFMNEW07.CSV")
ax.plot(t2, ch12)
print(get_peak_freq(t2, ch12))

t3, ch13 = load_csv("D:/data/WFMNEW09.CSV")
ax.plot(t3, ch13)
print(get_peak_freq(t3, ch13))

print("length of time", len(ch13) / 2.5e9)
print("length of time", len(ch13) / 8.33e6) # actually used


# [ 5.373296 38.923847 33.074005 22.505043 22.217746 43.071298  5.211336
#  35.171034 10.872007  5.61469 ]

# ax.set_xlim([0, 1e-5])
# Out:
# 1.8383334230957031
# 2.743333467285156
# 2.495000121826172
# length of time 4e-06
# length of time 0.0012004801920768306

# %%
def load_csv_two_channels(csv_file):
    data = np.genfromtxt(csv_file, delimiter=",", skip_header=1)
    t = np.asarray(data[:, 0], dtype=np.float32)
    ch1 = np.asarray(data[:, 1], dtype=np.float32)
    ch2 = np.asarray(data[:, 2], dtype=np.float32)
    return t, ch1, ch2

t, ch1, ch2 = load_csv_two_channels("./waveforms/test_scope.csv")
fig, ax = plt.subplots()
ax.plot(t, ch1)
ax.plot(t, ch2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
